# %%
import pandas as p
import numpy as n

# %%
x = p.read_excel("csc.XLSX")

# %%
data = p.DataFrame(x, columns=['Customer Name', 'Vehicle', 'Vehicle Reg. No.', 'Executive Name','First Contacted Date'])

# %%
print(data)
# Out:
#                   Customer Name                    Vehicle Vehicle Reg. No.  \
# 0                     KASHINATH                        NaN       XX09YY9999
# 1          jesangbhai v solanki                        NaN       XX09YY9999
# 2     santosh kumar vishwakarma                  ACE CRANE       XX09YY9999
# 3                    AHMAD RAZA               RENAULT KWID       XX09YY9999
# 4                          amit       SONALIKA TARCTOR 750       XX09YY9999
# ...                         ...                        ...              ...
# 3084                      Ajmat     Maruti Suzuki Alto K10       XX09YY9999
# 3085                Akash Verma  Piaggio Ape Auto Rickshaw       XX09YY9999
# 3086                HAMID HAMID       Mahindra Scorpio S11       XX09YY9999
# 3087      ABHISHEK KUMAR PATHAK             Tata Tiago CNG       XX09YY9999
# 3088          Liton Chakraborty        Bajaj Auto Rickshaw       XX09YY9999
#
#              Executive Name First Contacted Date
# ...

# %%
x=x.sort_values('First Contacted Date')

# %%
x
# Out:
#       Lead ID                  MFCW ID              Customer Name  \
# 3088  4063991  MKTG_CSC_1stApril203046          Liton Chakraborty
# 3087  4063990  MKTG_CSC_1stApril203045      ABHISHEK KUMAR PATHAK
# 3085  4067837  MKTG_CSC_4thApril203050                Akash Verma
# 3084  4067836  MKTG_CSC_4thApril203049                      Ajmat
# 3083  4067469  MKTG_CSC_4thApril203047   avinash subhash lokhande
# ...       ...                      ...                        ...
# 27    4715731   MKTG_CSC_14thAug206930          Hari dhyan Tiwari
# 26    4715730   MKTG_CSC_14thAug206929            RAVADA Latadevi
# 25    4715729   MKTG_CSC_14thAug206928  PRASHIK RAMKRUSHNA BADOLE
# 35    4715739   MKTG_CSC_14thAug206940            gindi mohan rao
# 0     4715704   MKTG_CSC_14thAug206902                  KASHINATH
#
#      Vehicle Reg. No.                    Vehicle       Status  ABM Status  \
# 3088       XX09YY9999        Bajaj Auto Rickshaw    Cancelled         NaN
# ...

# %%
o = p.open_excel("csc.XLSX")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 o = p.open_excel("csc.XLSX")
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\__init__.py:264, in __getattr__(name)
#     260     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     262     return _SparseArray
# --> 264 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'open_excel'

# %%
x.drop_duplicates()
# Out:
#       Lead ID                  MFCW ID              Customer Name  \
# 3088  4063991  MKTG_CSC_1stApril203046          Liton Chakraborty
# 3087  4063990  MKTG_CSC_1stApril203045      ABHISHEK KUMAR PATHAK
# 3085  4067837  MKTG_CSC_4thApril203050                Akash Verma
# 3084  4067836  MKTG_CSC_4thApril203049                      Ajmat
# 3083  4067469  MKTG_CSC_4thApril203047   avinash subhash lokhande
# ...       ...                      ...                        ...
# 27    4715731   MKTG_CSC_14thAug206930          Hari dhyan Tiwari
# 26    4715730   MKTG_CSC_14thAug206929            RAVADA Latadevi
# 25    4715729   MKTG_CSC_14thAug206928  PRASHIK RAMKRUSHNA BADOLE
# 35    4715739   MKTG_CSC_14thAug206940            gindi mohan rao
# 0     4715704   MKTG_CSC_14thAug206902                  KASHINATH
#
#      Vehicle Reg. No.                    Vehicle       Status  ABM Status  \
# 3088       XX09YY9999        Bajaj Auto Rickshaw    Cancelled         NaN
# ...

# %%
unique = x.Vehicle.unique() 
duplicates = len(x)-len(unique)
print("number of duplicate rows is:",duplicates)
# Out:
# number of duplicate rows is: 2484

# %%
unique = x.Status.unique() 
duplicates = len(x)-len(unique)
print("number of duplicate rows is:",duplicates)
# Out:
# number of duplicate rows is: 3083

# %%
unique = x.Lead Created Username.unique() 
duplicates = len(x)-len(unique)
print("number of duplicate rows is:",duplicates)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 unique = x.Lead_Created_Username.unique()
#       2 duplicates = len(x)-len(unique)
#       3 print("number of duplicate rows is:",duplicates)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Lead_Created_Username'

# %%
duplicate = x[x.duplicated()]

# %%
duplicate
# Out:
# Empty DataFrame
# Columns: [Lead ID, MFCW ID, Customer Name, Vehicle Reg. No., Vehicle, Status, ABM Status, Last Updated On, Executive Name, Executive SAP, ABM Name, ABM Sap, DM Name, DM Sap, CH Name, CH Sap, First Contacted Date, Created Type, Given For, Loan Agreement No., Branch, Branch Code, Final Application No., CC Initial Remarks, Remarks, Next Follow Up Date, In Progress, City, State, Lead For, Application No, Created On, Lead Type, Created by, Lead Created Username, Workable Month, CRM ID, Sap Code, DO Date, ABM Remarks, Emlap MMFSL Stage, Emlap MMFSL Code, Emlap Appl No, Emlap Finance Amount, Emlap Date Time, Lead Category, Call Duration, Call Tracked On, Vertical, Escalated]
# Index: []
#
# [0 rows x 50 columns]

# %%
sorted = x.sort_values('Last Updated On')

# %%
sorted
# Out:
#       Lead ID                  MFCW ID              Customer Name  \
# 3076  4077945  MKTG_CSC_6thApril203056              AVDHESH KUMAR
# 3087  4063990  MKTG_CSC_1stApril203045      ABHISHEK KUMAR PATHAK
# 3082  4070345  MKTG_CSC_5thApril203048      Prakash Sanjay Hegade
# 3077  4077946  MKTG_CSC_6thApril203057         Ganesh Gopal Pawar
# 3074  4077943  MKTG_CSC_6thApril203053         mukeshbhai vaghari
# ...       ...                      ...                        ...
# 27    4715731   MKTG_CSC_14thAug206930          Hari dhyan Tiwari
# 26    4715730   MKTG_CSC_14thAug206929            RAVADA Latadevi
# 25    4715729   MKTG_CSC_14thAug206928  PRASHIK RAMKRUSHNA BADOLE
# 35    4715739   MKTG_CSC_14thAug206940            gindi mohan rao
# 0     4715704   MKTG_CSC_14thAug206902                  KASHINATH
#
#      Vehicle Reg. No.                      Vehicle       Status  ABM Status  \
# 3076       XX09YY9999       Mahindra Bolero Pickup    Cancelled         NaN
# ...

# %%
new_sort = x.sort_values("Lead ID")

# %%
new_sort
# Out:
#       Lead ID                  MFCW ID             Customer Name  \
# 3087  4063990  MKTG_CSC_1stApril203045     ABHISHEK KUMAR PATHAK
# 3088  4063991  MKTG_CSC_1stApril203046         Liton Chakraborty
# 3083  4067469  MKTG_CSC_4thApril203047  avinash subhash lokhande
# 3084  4067836  MKTG_CSC_4thApril203049                     Ajmat
# 3085  4067837  MKTG_CSC_4thApril203050               Akash Verma
# ...       ...                      ...                       ...
# 41    4715745   MKTG_CSC_14thAug206946                M VARSHITH
# 42    4715746   MKTG_CSC_14thAug206947                  vishnu k
# 43    4715747   MKTG_CSC_14thAug206948         kanhiya bhatnagar
# 44    4715749   MKTG_CSC_14thAug206923           SANJU PRAJAPATI
# 45    4715750   MKTG_CSC_14thAug206937                prabhu jee
#
#      Vehicle Reg. No.                     Vehicle       Status  ABM Status  \
# 3087       XX09YY9999              Tata Tiago CNG  No Response         NaN
# ...

# %%
sort = x.sort_values("Lead ID" , ascending=False)

# %%
sort
# Out:
#       Lead ID                  MFCW ID             Customer Name  \
# 45    4715750   MKTG_CSC_14thAug206937                prabhu jee
# 44    4715749   MKTG_CSC_14thAug206923           SANJU PRAJAPATI
# 43    4715747   MKTG_CSC_14thAug206948         kanhiya bhatnagar
# 42    4715746   MKTG_CSC_14thAug206947                  vishnu k
# 41    4715745   MKTG_CSC_14thAug206946                M VARSHITH
# ...       ...                      ...                       ...
# 3085  4067837  MKTG_CSC_4thApril203050               Akash Verma
# 3084  4067836  MKTG_CSC_4thApril203049                     Ajmat
# 3083  4067469  MKTG_CSC_4thApril203047  avinash subhash lokhande
# 3088  4063991  MKTG_CSC_1stApril203046         Liton Chakraborty
# 3087  4063990  MKTG_CSC_1stApril203045     ABHISHEK KUMAR PATHAK
#
#      Vehicle Reg. No.                     Vehicle       Status  ABM Status  \
# 45         XX09YY9999                         NaN    Open Lead         NaN
# ...

# %%
a = p.read_excel("csc.XLSX")
b = p.read_excel("123.XLSX")

# %%
c = a.merge(b,how="left")
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 c = a.merge(b,how="left")
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:10093, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10074 @Substitution("")
#   10075 @Appender(_merge_doc, indents=2)
#   10076 def merge(
#    (...)
#   10089     validate: str | None = None,
#   10090 ) -> DataFrame:
#   10091     from pandas.core.reshape.merge import merge
# > 10093     return merge(
#   10094         self,
#   10095         right,
#   10096         how=how,
#   10097         on=on,
#   10098         left_on=left_on,
#   10099         right_on=right_on,
#   10100         left_index=left_index,
#   10101         right_index=right_index,
#   10102         sort=sort,
# ...

# %%
data.groupby(['Vehicle']).sum().plot(kind='pie', y = 'Vehicle')
# Out:
# C:\Users\4000067667\AppData\Local\Temp\ipykernel_7076\1088867990.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['Vehicle']).sum().plot(kind='pie', y = 'Vehicle')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %%
import Workbook, CellsHelper, FileFormatType, License
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import Workbook, CellsHelper, FileFormatType, License
#
# ModuleNotFoundError: No module named 'Workbook'

# %%
workbook = Workbook(csc.XLSX)
# Obtaining the reference of the first worksheet
worksheet = workbook.worksheets.get(0)
worksheet.cells.get("A2").put_value("Category1")
worksheet.cells.get("A3").put_value("Category2")
worksheet.cells.get("A4").put_value("Category3")
worksheet.cells.get("B1").put_value("Pie")
worksheet.cells.get("B2").put_value(300)
worksheet.cells.get("B3").put_value(400)
worksheet.cells.get("B4").put_value(200)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 workbook = Workbook(csc.XLSX)
#       2 # Obtaining the reference of the first worksheet
#       3 worksheet = workbook.worksheets.get(0)
#
# NameError: name 'Workbook' is not defined

# %%
chart1 =

# %%
import xlsxwriter
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import xlsxwriter
#
# ModuleNotFoundError: No module named 'xlsxwriter'

# %%
display(x.drop_duplicates())
# Out:
#       Lead ID                  MFCW ID              Customer Name  \
# 0     4715704   MKTG_CSC_14thAug206902                  KASHINATH
# 1     4715705   MKTG_CSC_14thAug206903       jesangbhai v solanki
# 2     4715706   MKTG_CSC_14thAug206904  santosh kumar vishwakarma
# 3     4715707   MKTG_CSC_14thAug206905                 AHMAD RAZA
# 4     4715708   MKTG_CSC_14thAug206906                       amit
# ...       ...                      ...                        ...
# 3084  4067836  MKTG_CSC_4thApril203049                      Ajmat
# 3085  4067837  MKTG_CSC_4thApril203050                Akash Verma
# 3086  4067838  MKTG_CSC_4thApril203051                HAMID HAMID
# 3087  4063990  MKTG_CSC_1stApril203045      ABHISHEK KUMAR PATHAK
# 3088  4063991  MKTG_CSC_1stApril203046          Liton Chakraborty
#
#      Vehicle Reg. No.                    Vehicle       Status  ABM Status  \
# 0          XX09YY9999                        NaN    Open Lead         NaN
# ...

# %%
print()

# %%
x.sort_values("Vehicle", inplace=True)
x.drop_duplicates(subset="Vehicle",keep=False, inplace=True)

# %%
x
# Out:
#       Lead ID                  MFCW ID                    Customer Name  \
# 2     4715706   MKTG_CSC_14thAug206904        santosh kumar vishwakarma
# 800   4599880  MKTG_CSC_11thJuly206058                     SATYAJIT DAS
# 487   4667612  MKTG_CSC_27thJuly206482            vishal singh pathania
# 472   4667597  MKTG_CSC_27thJuly206466  Ravibhai Dineshbhai dudharejiya
# 885   4583164   MKTG_CSC_6thJuly206008                   Govind sharama
# ...       ...                      ...                              ...
# 755   4627453  MKTG_CSC_15thJuly206158            SUBRAMANI GOVINDASAMY
# 411   4675201  MKTG_CSC_31stJuly206553                    SHRTITAM kUMA
# 346   4677598    MKTG_CSC_1stAug206574         DEVENDRA DHANLAL BAHEKAR
# 2881  4269767    MKTG_CSC_8thMay203305                    sayfulla khan
# 452   4667577  MKTG_CSC_27thJuly206445                         SHAJAHAN
#
#      Vehicle Reg. No.                    Vehicle       Status  ABM Status  \
# ...

# %%
i = p.read_excel("csc.XLSX")

# %%
i
# Out:
#       Lead ID                  MFCW ID              Customer Name  \
# 0     4715704   MKTG_CSC_14thAug206902                  KASHINATH
# 1     4715705   MKTG_CSC_14thAug206903       jesangbhai v solanki
# 2     4715706   MKTG_CSC_14thAug206904  santosh kumar vishwakarma
# 3     4715707   MKTG_CSC_14thAug206905                 AHMAD RAZA
# 4     4715708   MKTG_CSC_14thAug206906                       amit
# ...       ...                      ...                        ...
# 3084  4067836  MKTG_CSC_4thApril203049                      Ajmat
# 3085  4067837  MKTG_CSC_4thApril203050                Akash Verma
# 3086  4067838  MKTG_CSC_4thApril203051                HAMID HAMID
# 3087  4063990  MKTG_CSC_1stApril203045      ABHISHEK KUMAR PATHAK
# 3088  4063991  MKTG_CSC_1stApril203046          Liton Chakraborty
#
#      Vehicle Reg. No.                    Vehicle       Status  ABM Status  \
# 0          XX09YY9999                        NaN    Open Lead         NaN
# ...

# %%
i.drop_duplicates()
# Out:
#       Lead ID                  MFCW ID              Customer Name  \
# 0     4715704   MKTG_CSC_14thAug206902                  KASHINATH
# 1     4715705   MKTG_CSC_14thAug206903       jesangbhai v solanki
# 2     4715706   MKTG_CSC_14thAug206904  santosh kumar vishwakarma
# 3     4715707   MKTG_CSC_14thAug206905                 AHMAD RAZA
# 4     4715708   MKTG_CSC_14thAug206906                       amit
# ...       ...                      ...                        ...
# 3084  4067836  MKTG_CSC_4thApril203049                      Ajmat
# 3085  4067837  MKTG_CSC_4thApril203050                Akash Verma
# 3086  4067838  MKTG_CSC_4thApril203051                HAMID HAMID
# 3087  4063990  MKTG_CSC_1stApril203045      ABHISHEK KUMAR PATHAK
# 3088  4063991  MKTG_CSC_1stApril203046          Liton Chakraborty
#
#      Vehicle Reg. No.                    Vehicle       Status  ABM Status  \
# 0          XX09YY9999                        NaN    Open Lead         NaN
# ...

# %%
i.sort_values("Stdsadsace = True)
i.drop_duplicates(subset= "Status" , keep = False , inplace = True)

# %%
i
# Out:
# Empty DataFrame
# Columns: [Lead ID, MFCW ID, Customer Name, Vehicle Reg. No., Vehicle, Status, ABM Status, Last Updated On, Executive Name, Executive SAP, ABM Name, ABM Sap, DM Name, DM Sap, CH Name, CH Sap, First Contacted Date, Created Type, Given For, Loan Agreement No., Branch, Branch Code, Final Application No., CC Initial Remarks, Remarks, Next Follow Up Date, In Progress, City, State, Lead For, Application No, Created On, Lead Type, Created by, Lead Created Username, Workable Month, CRM ID, Sap Code, DO Date, ABM Remarks, Emlap MMFSL Stage, Emlap MMFSL Code, Emlap Appl No, Emlap Finance Amount, Emlap Date Time, Lead Category, Call Duration, Call Tracked On, Vertical, Escalated]
# Index: []
#
# [0 rows x 50 columns]

# %%
import matplotlib.pyplot as plt

# %%
sorted_by_production = x.sort_values(['Vehicle'], ascending=False).head(10)
sorted_by_production['Vehicle'].head(10).plot(kind="barh")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 sorted_by_production = x.sort_values(['Vehicle'], ascending=False).head(10)
# ----> 2 sorted_by_production['Vehicle'].head(10).plot(kind="barh")
#       3 plt.show()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1000, in PlotAccessor.__call__(self, *args, **kwargs)
#     997             label_name = label_kw or data.columns
#     998             data.columns = label_name
# -> 1000 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...

# %%
y = p.read_excel("csc.XLSX")

# %%
y['Vehicle'].to_list().count('PIAGGIO APE')
# Out:
# 5

# %%
print(y["Vehicle"].unique())
# Out:
# [nan 'ACE CRANE' 'RENAULT KWID' 'SONALIKA TARCTOR 750' 'MARUTI EECO 7 STR'
#  'TATA MAGIC PLUS' 'TATA ULTRA' 'RENAULT TRIBER' 'MAHINDRA BLAZO 48 CBC'
#  'TATA MAGIC' 'MARUTI ERTIGA' 'PIAGGIO APE' 'HONDA CITY'
#  'MARUTI SUPER CARRY' 'Bajaj Discover' 'MARUTI EECO' 'BAJAJ AUTO'
#  'MAHINDRA BOLERO CAMPER ZLX' 'SONALIKA TARCTOR 745' 'TOYOTA INNOVA'
#  'MARUTU SWIFT' 'MARUTI ALTO 800' 'MAHINDRA BOLERO' 'MAHINDRA TREO'
#  'MAHINDRA TARCTOR ARJUN 555' 'SPELDORE' 'BAJAJ AUTO CNG' 'MAHINDRA ALFA'
#  'POWERTRACK TRACTOR 439 PLUS' 'SULTAN DLX E RICKSHAW'
#  'MAHINDRA BOLERO PICKUP' 'MARUTI ALTO K10' 'MAHINDRA SCORPIO'
#  'MARUTI SWIFT DZIRE' 'TATA 1616' 'MARUTI ALTO' 'JCB 3DX'
#  'MAHINDRA TARCTOR 275' 'MARUTI CIAZ' 'MARUTI WAGON R' 'MAHINDRA THAR'
#  'MARUTI NEXA IGNIS' 'MARUTI NEW BALENO' 'MAHINDRA BOLERO PICKUP BS4'
#  'TATA WINGER' 'MARUTI SUZUKI XL 6' 'BAJAJ CNG AUTO' 'EICHER PRO 1110'
#  'MARUTI DZIRE VXI CNG' 'HYUNDAI AURA' 'MASSEY FERGUSION 245'
# ...

# %%
print(y['Status'].unique)
# Out:
# <bound method Series.unique of 0         Open Lead
# 1         Open Lead
# 2         Open Lead
# 3         Open Lead
# 4         Open Lead
#            ...
# 3084      Cancelled
# 3085      Follow Up
# 3086    No Response
# 3087    No Response
# 3088      Cancelled
# Name: Status, Length: 3089, dtype: object>

# %%
y['Vehicle'].nunique()
# Out:
# 604

# %%
y['Executive Name'].nunique()
# Out:
# 393

# %%
y['Executive SAP'].nunique()
# Out:
# 393

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 2
#       1 import matplotlib
# ----> 2 matplotlib.__version_
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\matplotlib\_api\__init__.py:226, in caching_module_getattr.<locals>.__getattr__(name)
#     224 if name in props:
#     225     return props[name].__get__(instance)
# --> 226 raise AttributeError(
#     227     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute '__version_'
